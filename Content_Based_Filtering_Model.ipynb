# %% [markdown]
# # Content-based Filtering Recommendation Model

# %% [markdown]
# This notebook shows the whole process of content-based filtering model development. The model includes three different pillar:
# 1- Text creation for each book
# 2- Similarity calculation based on text
# 3- Recommending the k-most similar books to readers

# %% [markdown]
# #### Import packages and data

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import re
import time
import tqdm as td

# path
root_path ='/content/gdrive/MyDrive/MasterThesis/Data/KULrecommender'  #change dir to your project folder
#%cd root_path
os.chdir(root_path)
os.listdir()

# %%
# Reading the book data with summaries extracted from Google Books API
df_books = pd.read_csv("book_summaries_final.csv", sep=',') 
df_books = df_books.drop(['Unnamed: 0'], axis=1).reset_index()
#saving book titles for further use
df_books['titelnr'].to_csv('book_titles_from_book_summaries.csv')
df_books
# Out:
#          index   exem_id  titelnr  \
# 0            0  24442024  4145849
# 1            1  16825235  1536557
# 2            2  16826563   770735
# 3            3  16828808   539177
# 4            4  16831632  1922287
# ...        ...       ...      ...
# 104610  104610  16880738   583407
# 104611  104611  16882082   579988
# 104612  104612  17124549   941209
# 104613  104613  17025805  1168675
# 104614  104614  16979489  1193770
#
#                                                      isbn  \
# 0                                           9782221243596
# 1                                           9789049807245
# 2                                           9789028422087
# 3       9056175629, 9057593211, 9789056175627, 9789057...
# 4                                           9789403185705
# ...                                                   ...
# 104610                          2849020664, 9782849020661
# 104611                          9066484276, 9789066484276
# 104612                                      9789066488427
# 104613                                      9789460772832
# 104614                                      9789030136309
#
#                                                book_title  \
# 0                                             Noa : roman
# 1       Zondagskind : alsof opgroeien nog niet lastig ...
# 2                            Bekentenissen van een burger
# 3                                 Mijn broer bijvoorbeeld
# 4                                         De vreemdelinge
# ...                                                   ...
# 104610  Le nouveau petit Robert : dictionnaire alphabé...
# 104611  Van Dale groot woordenboek van de Nederlandse ...
# 104612         Van Dale beeldwoordenboek Nederlands-Turks
# 104613  Het Groene Boekje : woordenlijst Nederlandse taal
# 104614                       Plantyn algemene wereldatlas
#
#                     original_title  \
# 0                              NaN
# 1                              NaN
# 2            Egy polgár vallomásai
# 3       Am Beispiel meines Bruders
# 4                     La straniera
# ...                            ...
# 104610                         NaN
# 104611                         NaN
# 104612  The mini visual dictionary
# 104613                         NaN
# 104614                         NaN
#
#                                              book_summary  \
# 0       "9 hackers combattent un dictateur. Des vies s...
# 1                                                     NaN
# 2       Autobiografisch relaas van een jeugd voor de E...
# 3       Autobiografisch getint relaas waarin een Duits...
# 4       Het levensverhaal van de auteur waarin ze besc...
# ...                                                   ...
# 104610  Découvrez la vie des mots : leur étymologie et...
# 104611                                                NaN
# 104612                                                NaN
# 104613                                                NaN
# 104614                                                NaN
#
#                                        publisher          collation  \
# 0          Paris : Robert Laffont/Versilio, 2022      367 p. : ill.
# 1              [Amsterdam] : Dwarsligger, © 2019     971 p. ; 12 cm
# 2       Amsterdam : Wereldbibliotheek, cop. 2007             463 p.
# 3                       Amsterdam : Podium, 2004             151 p.
# 4                Amsterdam : De Bezige Bij, 2020             284 p.
# ...                                          ...                ...
# 104610     Paris : Dictionnaires Le Robert, 2005    XXXVII, 2949 p.
# 104611     Utrecht : Van Dale Lexicografie, 2005     3 dl. + cd-rom
# 104612                  Utrecht : Van Dale, 2010  VI, 598 p. : ill.
# 104613                  Utrecht : Van Dale, 2015            1207 p.
# 104614                  Mechelen : Plantyn, 2015   X, 191 p. : ill.
#
#                  edition awards material        primary_author  \
# 0                    NaN    NaN     Boek            Levy, Marc
# 1                    NaN    NaN     Boek        Visser, Judith
# 2                    NaN    NaN     Boek         Márai, Sándor
# 3                    NaN    NaN     Boek             Timm, Uwe
# 4                    NaN    NaN     Boek   Durastanti, Claudia
# ...                  ...    ...      ...                   ...
# 104610         Nouv. éd.    NaN     Boek          Robert, Paul
# 104611  14de herz. uitg.    NaN     Boek         Den Boon, Ton
# 104612                 1    NaN     Boek  Corbeil, Jean-Claude
# 104613                 1    NaN     Boek  Nederlandse Taalunie
# 104614       Editie 2012    NaN     Boek    Van Hecke, Etienne
#
#         publication_date language original_language  \
# 0                 2022.0      FRE               NaN
# 1                 2019.0      DUT               NaN
# 2                 2007.0      DUT               HUN
# 3                 2004.0      DUT               GER
# 4                 2020.0      DUT               ITA
# ...                  ...      ...               ...
# 104610            2005.0      FRE               NaN
# 104611            2005.0      DUT               NaN
# 104612            2010.0      DUT               ENG
# 104613            2015.0      DUT               NaN
# 104614            2015.0      DUT               NaN
#
#                          location item_type
# 0       de Bib Leuven Tweebronnen        B2
# 1       de Bib Leuven Tweebronnen        B2
# 2       de Bib Leuven Tweebronnen        B2
# 3       de Bib Leuven Tweebronnen        B2
# 4       de Bib Leuven Tweebronnen        B2
# ...                           ...       ...
# 104610      Hulpgevangenis Leuven        ZZ
# 104611      Hulpgevangenis Leuven        ZZ
# 104612      Hulpgevangenis Leuven        ZZ
# 104613      Hulpgevangenis Leuven        ZZ
# 104614      Hulpgevangenis Leuven        ZZ
#
# [104615 rows x 18 columns]

# %%
# Read topic datafile
df_topics = pd.read_csv('KUL_topics.csv', sep="\t")
# Remove the unneccesary books which is not in the df_books
df_topics = df_topics[df_topics['titelnr'].isin(df_books['titelnr'])]
df_topics
# Out:
#          titelnr        topic_type                        topic
# 0        4145849             genre             Ideeënliteratuur
# 1        4145849             genre                       Romans
# 2        4145849             topic                       Hacken
# 3        1536557             genre  Autobiografische literatuur
# 4        1536557             genre          Ontwikkelingsromans
# ...          ...               ...                          ...
# 2598250   576591  additional_topic                  wereldatlas
# 2598251   576591  additional_topic    Aardrijkskunde ; atlassen
# 2598252   576591  additional_topic          Informatieve werken
# 2598253   576591  additional_topic                  950.6 LEESZ
# 2598254  1193770             topic               Wereldatlassen
#
# [2451956 rows x 3 columns]

# %% [markdown]
# ### Grouping genres, topics, additional topics

# %%
# Group books with titelnr 
df = df_topics.drop_duplicates(['titelnr', 'topic_type', 'topic'])
# group the DataFrame by titelnr and type, and apply the join function to the value column
genres_df = df[df['topic_type'] == 'genre'].groupby('titelnr')['topic'].apply(', '.join).reset_index()
topics_df = df[df['topic_type'] == 'topic'].groupby('titelnr')['topic'].apply(', '.join).reset_index()
additional_topics_df = df[df['topic_type'] == 'additional_topic'].groupby('titelnr')['topic'].apply(', '.join).reset_index()

# merge the three DataFrames on the titelnr column
merged_df = pd.merge(genres_df, topics_df, on='titelnr', how='outer')
merged_df = pd.merge(merged_df, additional_topics_df, on='titelnr', how='outer')
# fill missing values with empty strings
merged_df.fillna('', inplace=True)
# rename columns
merged_df = merged_df.rename(columns={'topic_x': 'genre', 'topic_y': 'topic', 'topic' : 'additional_topic'})
# display the merged DataFrame
merged_df
# Out:
#         titelnr                                            genre  \
# 0            53                                         Verhalen
# 1            58                                       Cursiefjes
# 2           313                                         Verhalen
# 3           628                                           Romans
# 4           968  Biografische literatuur, Historische literatuur
# ...         ...                                              ...
# 104050  3234265
# 104051  3345229
# 104052  3358827
# 104053  3409218
# 104054  3556898
#
#                                                     topic  \
# 0
# 1
# 2
# 3       Natuur, Obsessionele liefde, Platteland; Noorw...
# 4                                               Rembrandt
# ...                                                   ...
# 104050
# 104051
# 104052
# 104053
# 104054
#
#                                          additional_topic
# 0                                    verhalen, Cursiefjes
# 1               Pensioen, Cursiefjes, Humoristische roman
# 2                          verhalen, VER, Verhalenbundels
# 3                              liefde, Romans, Nobelprijs
# 4       Rembrandt, biografieën, Romans, BIO, HIS, Remb...
# ...                                                   ...
# 104050  verhalen, levensvragen, obsessies, Psychologis...
# 104051  godsdiensten, vriendschap, liefde, Historisch,...
# 104052  symboliek, Kelten, Keltische kunst, 913.7, sym...
# 104053                                    Fantasy (volw.)
# 104054  Verfilmde boeken, Vlaamse auteurs, Platteland ...
#
# [104055 rows x 4 columns]

# %%
#merge df books and grouped books 
df = pd.merge(df_books, merged_df, on='titelnr', how='outer')
df
# Out:
#          index   exem_id  titelnr  \
# 0            0  24442024  4145849
# 1            1  16825235  1536557
# 2            2  16826563   770735
# 3            3  16828808   539177
# 4            4  16831632  1922287
# ...        ...       ...      ...
# 104610  104610  16880738   583407
# 104611  104611  16882082   579988
# 104612  104612  17124549   941209
# 104613  104613  17025805  1168675
# 104614  104614  16979489  1193770
#
#                                                      isbn  \
# 0                                           9782221243596
# 1                                           9789049807245
# 2                                           9789028422087
# 3       9056175629, 9057593211, 9789056175627, 9789057...
# 4                                           9789403185705
# ...                                                   ...
# 104610                          2849020664, 9782849020661
# 104611                          9066484276, 9789066484276
# 104612                                      9789066488427
# 104613                                      9789460772832
# 104614                                      9789030136309
#
#                                                book_title  \
# 0                                             Noa : roman
# 1       Zondagskind : alsof opgroeien nog niet lastig ...
# 2                            Bekentenissen van een burger
# 3                                 Mijn broer bijvoorbeeld
# 4                                         De vreemdelinge
# ...                                                   ...
# 104610  Le nouveau petit Robert : dictionnaire alphabé...
# 104611  Van Dale groot woordenboek van de Nederlandse ...
# 104612         Van Dale beeldwoordenboek Nederlands-Turks
# 104613  Het Groene Boekje : woordenlijst Nederlandse taal
# 104614                       Plantyn algemene wereldatlas
#
#                     original_title  \
# 0                              NaN
# 1                              NaN
# 2            Egy polgár vallomásai
# 3       Am Beispiel meines Bruders
# 4                     La straniera
# ...                            ...
# 104610                         NaN
# 104611                         NaN
# 104612  The mini visual dictionary
# 104613                         NaN
# 104614                         NaN
#
#                                              book_summary  \
# 0       "9 hackers combattent un dictateur. Des vies s...
# 1                                                     NaN
# 2       Autobiografisch relaas van een jeugd voor de E...
# 3       Autobiografisch getint relaas waarin een Duits...
# 4       Het levensverhaal van de auteur waarin ze besc...
# ...                                                   ...
# 104610  Découvrez la vie des mots : leur étymologie et...
# 104611                                                NaN
# 104612                                                NaN
# 104613                                                NaN
# 104614                                                NaN
#
#                                        publisher          collation  \
# 0          Paris : Robert Laffont/Versilio, 2022      367 p. : ill.
# 1              [Amsterdam] : Dwarsligger, © 2019     971 p. ; 12 cm
# 2       Amsterdam : Wereldbibliotheek, cop. 2007             463 p.
# 3                       Amsterdam : Podium, 2004             151 p.
# 4                Amsterdam : De Bezige Bij, 2020             284 p.
# ...                                          ...                ...
# 104610     Paris : Dictionnaires Le Robert, 2005    XXXVII, 2949 p.
# 104611     Utrecht : Van Dale Lexicografie, 2005     3 dl. + cd-rom
# 104612                  Utrecht : Van Dale, 2010  VI, 598 p. : ill.
# 104613                  Utrecht : Van Dale, 2015            1207 p.
# 104614                  Mechelen : Plantyn, 2015   X, 191 p. : ill.
#
#                  edition  ... material        primary_author publication_date  \
# 0                    NaN  ...     Boek            Levy, Marc           2022.0
# 1                    NaN  ...     Boek        Visser, Judith           2019.0
# 2                    NaN  ...     Boek         Márai, Sándor           2007.0
# 3                    NaN  ...     Boek             Timm, Uwe           2004.0
# 4                    NaN  ...     Boek   Durastanti, Claudia           2020.0
# ...                  ...  ...      ...                   ...              ...
# 104610         Nouv. éd.  ...     Boek          Robert, Paul           2005.0
# 104611  14de herz. uitg.  ...     Boek         Den Boon, Ton           2005.0
# 104612                 1  ...     Boek  Corbeil, Jean-Claude           2010.0
# 104613                 1  ...     Boek  Nederlandse Taalunie           2015.0
# 104614       Editie 2012  ...     Boek    Van Hecke, Etienne           2015.0
#
#         language original_language                   location item_type  \
# 0            FRE               NaN  de Bib Leuven Tweebronnen        B2
# 1            DUT               NaN  de Bib Leuven Tweebronnen        B2
# 2            DUT               HUN  de Bib Leuven Tweebronnen        B2
# 3            DUT               GER  de Bib Leuven Tweebronnen        B2
# 4            DUT               ITA  de Bib Leuven Tweebronnen        B2
# ...          ...               ...                        ...       ...
# 104610       FRE               NaN      Hulpgevangenis Leuven        ZZ
# 104611       DUT               NaN      Hulpgevangenis Leuven        ZZ
# 104612       DUT               ENG      Hulpgevangenis Leuven        ZZ
# 104613       DUT               NaN      Hulpgevangenis Leuven        ZZ
# 104614       DUT               NaN      Hulpgevangenis Leuven        ZZ
#
#                                                     genre  \
# 0                                Ideeënliteratuur, Romans
# 1       Autobiografische literatuur, Ontwikkelingsroma...
# 2        Autobiografische literatuur, Ontwikkelingsromans
# 3                             Autobiografische literatuur
# 4                     Autobiografische literatuur, Romans
# ...                                                   ...
# 104610
# 104611
# 104612
# 104613
# 104614
#
#                                                     topic  \
# 0                                                  Hacken
# 1       Autismespectrumstoornissen, Tijdsbeeld; 1980-1...
# 2       Europa; 1900-1945, Oostenrijks-Hongaarse monar...
# 3       Kinderen van nazi's, Schuldvraag; Wereldoorlog...
# 4                           Doofheid, Durastanti, Claudia
# ...                                                   ...
# 104610                         Franse taal; woordenboeken
# 104611                    Nederlandse taal; woordenboeken
# 104612                    Turkse taal; beeldwoordenboeken
# 104613                               Nederlandse spelling
# 104614                                     Wereldatlassen
#
#                                          additional_topic
# 0
# 1       Autisme, Aspergersyndroom, Ontwikkelingsromans...
# 2       Europa, 1900 - 1945, Autobiografische literatu...
# 3       autobiografieën, Wereldoorlog II, Autobiografi...
# 4       autobiografieën, Waargebeurd, doofheid, Autobi...
# ...                                                   ...
# 104610
# 104611  Nederlandse taal ; woordenboeken, Nederlands w...
# 104612  Nederlandse taal voor anderstaligen, Taalpunt,...
# 104613  woordenboeken, Nederlandse taal, spelling, Taa...
# 104614
#
# [104615 rows x 21 columns]

# %%
# merge columns into new column called "df_merged"
df['df_merged'] = df.apply(lambda row: f" {row['genre']}, {row['additional_topic']}, {row['topic']}", axis=1)
# display the DataFrame with the new column
df[['df_merged']]
# Out:
#                                                 df_merged
# 0                      Ideeënliteratuur, Romans, , Hacken
# 1        Autobiografische literatuur, Ontwikkelingsrom...
# 2        Autobiografische literatuur, Ontwikkelingsrom...
# 3        Autobiografische literatuur, autobiografieën,...
# 4        Autobiografische literatuur, Romans, autobiog...
# ...                                                   ...
# 104610                     , , Franse taal; woordenboeken
# 104611   , Nederlandse taal ; woordenboeken, Nederland...
# 104612   , Nederlandse taal voor anderstaligen, Taalpu...
# 104613   , woordenboeken, Nederlandse taal, spelling, ...
# 104614                                 , , Wereldatlassen
#
# [104615 rows x 1 columns]

# %%
# Define a function to remove duplicate words from a string to create simplest text as much as possible 
def remove_duplicates(text):
    # Split the text into a list of words
    words = text.split()
    # Create an empty set to keep track of unique words
    unique_words = set()
    # Create an empty list to hold the result words
    result_words = []
    # Loop through each word in the list of words
    for word in words:
        # If the word is not already in the set of unique words, add it to the set and the result list
        if word not in unique_words:
            unique_words.add(word)
            result_words.append(word)
    # Join the result words list back into a string
    result = " ".join(result_words)
    return result

# Apply the function to the 'text' column of the dataframe separately for each row
df['df_merged'] = df['df_merged'].apply(lambda x: remove_duplicates(x))
df
# Out:
#          index   exem_id  titelnr  \
# 0            0  24442024  4145849
# 1            1  16825235  1536557
# 2            2  16826563   770735
# 3            3  16828808   539177
# 4            4  16831632  1922287
# ...        ...       ...      ...
# 104610  104610  16880738   583407
# 104611  104611  16882082   579988
# 104612  104612  17124549   941209
# 104613  104613  17025805  1168675
# 104614  104614  16979489  1193770
#
#                                                      isbn  \
# 0                                           9782221243596
# 1                                           9789049807245
# 2                                           9789028422087
# 3       9056175629, 9057593211, 9789056175627, 9789057...
# 4                                           9789403185705
# ...                                                   ...
# 104610                          2849020664, 9782849020661
# 104611                          9066484276, 9789066484276
# 104612                                      9789066488427
# 104613                                      9789460772832
# 104614                                      9789030136309
#
#                                                book_title  \
# 0                                             Noa : roman
# 1       Zondagskind : alsof opgroeien nog niet lastig ...
# 2                            Bekentenissen van een burger
# 3                                 Mijn broer bijvoorbeeld
# 4                                         De vreemdelinge
# ...                                                   ...
# 104610  Le nouveau petit Robert : dictionnaire alphabé...
# 104611  Van Dale groot woordenboek van de Nederlandse ...
# 104612         Van Dale beeldwoordenboek Nederlands-Turks
# 104613  Het Groene Boekje : woordenlijst Nederlandse taal
# 104614                       Plantyn algemene wereldatlas
#
#                     original_title  \
# 0                              NaN
# 1                              NaN
# 2            Egy polgár vallomásai
# 3       Am Beispiel meines Bruders
# 4                     La straniera
# ...                            ...
# 104610                         NaN
# 104611                         NaN
# 104612  The mini visual dictionary
# 104613                         NaN
# 104614                         NaN
#
#                                              book_summary  \
# 0       "9 hackers combattent un dictateur. Des vies s...
# 1                                                     NaN
# 2       Autobiografisch relaas van een jeugd voor de E...
# 3       Autobiografisch getint relaas waarin een Duits...
# 4       Het levensverhaal van de auteur waarin ze besc...
# ...                                                   ...
# 104610  Découvrez la vie des mots : leur étymologie et...
# 104611                                                NaN
# 104612                                                NaN
# 104613                                                NaN
# 104614                                                NaN
#
#                                        publisher          collation  \
# 0          Paris : Robert Laffont/Versilio, 2022      367 p. : ill.
# 1              [Amsterdam] : Dwarsligger, © 2019     971 p. ; 12 cm
# 2       Amsterdam : Wereldbibliotheek, cop. 2007             463 p.
# 3                       Amsterdam : Podium, 2004             151 p.
# 4                Amsterdam : De Bezige Bij, 2020             284 p.
# ...                                          ...                ...
# 104610     Paris : Dictionnaires Le Robert, 2005    XXXVII, 2949 p.
# 104611     Utrecht : Van Dale Lexicografie, 2005     3 dl. + cd-rom
# 104612                  Utrecht : Van Dale, 2010  VI, 598 p. : ill.
# 104613                  Utrecht : Van Dale, 2015            1207 p.
# 104614                  Mechelen : Plantyn, 2015   X, 191 p. : ill.
#
#                  edition  ...        primary_author publication_date language  \
# 0                    NaN  ...            Levy, Marc           2022.0      FRE
# 1                    NaN  ...        Visser, Judith           2019.0      DUT
# 2                    NaN  ...         Márai, Sándor           2007.0      DUT
# 3                    NaN  ...             Timm, Uwe           2004.0      DUT
# 4                    NaN  ...   Durastanti, Claudia           2020.0      DUT
# ...                  ...  ...                   ...              ...      ...
# 104610         Nouv. éd.  ...          Robert, Paul           2005.0      FRE
# 104611  14de herz. uitg.  ...         Den Boon, Ton           2005.0      DUT
# 104612                 1  ...  Corbeil, Jean-Claude           2010.0      DUT
# 104613                 1  ...  Nederlandse Taalunie           2015.0      DUT
# 104614       Editie 2012  ...    Van Hecke, Etienne           2015.0      DUT
#
#         original_language                   location item_type  \
# 0                     NaN  de Bib Leuven Tweebronnen        B2
# 1                     NaN  de Bib Leuven Tweebronnen        B2
# 2                     HUN  de Bib Leuven Tweebronnen        B2
# 3                     GER  de Bib Leuven Tweebronnen        B2
# 4                     ITA  de Bib Leuven Tweebronnen        B2
# ...                   ...                        ...       ...
# 104610                NaN      Hulpgevangenis Leuven        ZZ
# 104611                NaN      Hulpgevangenis Leuven        ZZ
# 104612                ENG      Hulpgevangenis Leuven        ZZ
# 104613                NaN      Hulpgevangenis Leuven        ZZ
# 104614                NaN      Hulpgevangenis Leuven        ZZ
#
#                                                     genre  \
# 0                                Ideeënliteratuur, Romans
# 1       Autobiografische literatuur, Ontwikkelingsroma...
# 2        Autobiografische literatuur, Ontwikkelingsromans
# 3                             Autobiografische literatuur
# 4                     Autobiografische literatuur, Romans
# ...                                                   ...
# 104610
# 104611
# 104612
# 104613
# 104614
#
#                                                     topic  \
# 0                                                  Hacken
# 1       Autismespectrumstoornissen, Tijdsbeeld; 1980-1...
# 2       Europa; 1900-1945, Oostenrijks-Hongaarse monar...
# 3       Kinderen van nazi's, Schuldvraag; Wereldoorlog...
# 4                           Doofheid, Durastanti, Claudia
# ...                                                   ...
# 104610                         Franse taal; woordenboeken
# 104611                    Nederlandse taal; woordenboeken
# 104612                    Turkse taal; beeldwoordenboeken
# 104613                               Nederlandse spelling
# 104614                                     Wereldatlassen
#
#                                          additional_topic  \
# 0
# 1       Autisme, Aspergersyndroom, Ontwikkelingsromans...
# 2       Europa, 1900 - 1945, Autobiografische literatu...
# 3       autobiografieën, Wereldoorlog II, Autobiografi...
# 4       autobiografieën, Waargebeurd, doofheid, Autobi...
# ...                                                   ...
# 104610
# 104611  Nederlandse taal ; woordenboeken, Nederlands w...
# 104612  Nederlandse taal voor anderstaligen, Taalpunt,...
# 104613  woordenboeken, Nederlandse taal, spelling, Taa...
# 104614
#
#                                                 df_merged
# 0                      Ideeënliteratuur, Romans, , Hacken
# 1       Autobiografische literatuur, Ontwikkelingsroma...
# 2       Autobiografische literatuur, Ontwikkelingsroma...
# 3       Autobiografische literatuur, autobiografieën, ...
# 4       Autobiografische literatuur, Romans, autobiogr...
# ...                                                   ...
# 104610                       , Franse taal; woordenboeken
# 104611  , Nederlandse taal ; woordenboeken, Nederlands...
# 104612  , Nederlandse taal voor anderstaligen, Taalpun...
# 104613  , woordenboeken, Nederlandse taal, spelling, T...
# 104614                                   , Wereldatlassen
#
# [104615 rows x 22 columns]

# %% [markdown]
# ### 1- Creating text content for each book

# %%
# Text creation for each book
# This code merges genre/topic/additional topic,
# book title if it has no summary or too short summary, primary author, 
# language, book summary, and awards if there is any for each book. 

# merge columns into new column called "merged_info"
df['merged_info'] = df.apply(lambda row: f"{row['df_merged']}" + (f" {row['book_title']} by " if (pd.isna(row['book_summary'])) or len(row['book_summary']) < 40 else "") + f" {row['primary_author']} {row['language']} {'' if pd.isna(row['book_summary']) else row['book_summary']} " + 
                                (f" {row['awards']}" if not pd.isna(row['awards']) else ""), 
                            axis=1)
#save teh data frame 
df.to_csv('df_merged_info2.csv')
# display the DataFrame with the new column
df[['merged_info']]
# Out:
#                                               merged_info
# 0       Ideeënliteratuur, Romans, , Hacken Levy, Marc ...
# 1       Autobiografische literatuur, Ontwikkelingsroma...
# 2       Autobiografische literatuur, Ontwikkelingsroma...
# 3       Autobiografische literatuur, autobiografieën, ...
# 4       Autobiografische literatuur, Romans, autobiogr...
# ...                                                   ...
# 104610  , Franse taal; woordenboeken Robert, Paul FRE ...
# 104611  , Nederlandse taal ; woordenboeken, Nederlands...
# 104612  , Nederlandse taal voor anderstaligen, Taalpun...
# 104613  , woordenboeken, Nederlandse taal, spelling, T...
# 104614  , Wereldatlassen Plantyn algemene wereldatlas ...
#
# [104615 rows x 1 columns]

# %%
# read the dataframe with book texts
df_merged_info = pd.read_csv("df_merged_info2.csv", sep=',')
# extracting merged_info column
df_merged_info[['merged_info']]
# saving the merged_info column
df.to_csv('df_merged_info.csv')
# Out:
#                                               merged_info
# 0       Ideeënliteratuur, Romans, , Hacken Levy, Marc ...
# 1       Autobiografische literatuur, Ontwikkelingsroma...
# 2       Autobiografische literatuur, Ontwikkelingsroma...
# 3       Autobiografische literatuur, autobiografieën, ...
# 4       Autobiografische literatuur, Romans, autobiogr...
# ...                                                   ...
# 104610  , Franse taal; woordenboeken Robert, Paul FRE ...
# 104611  , Nederlandse taal ; woordenboeken, Nederlands...
# 104612  , Nederlandse taal voor anderstaligen, Taalpun...
# 104613  , woordenboeken, Nederlandse taal, spelling, T...
# 104614  , Wereldatlassen Plantyn algemene wereldatlas ...
#
# [104615 rows x 1 columns]

# %%
# add a new column with the length of each text string
df["text_length"] = df["merged_info"].apply(len)
df
# Out:
#          index   exem_id  titelnr  \
# 0            0  24442024  4145849
# 1            1  16825235  1536557
# 2            2  16826563   770735
# 3            3  16828808   539177
# 4            4  16831632  1922287
# ...        ...       ...      ...
# 104610  104610  16880738   583407
# 104611  104611  16882082   579988
# 104612  104612  17124549   941209
# 104613  104613  17025805  1168675
# 104614  104614  16979489  1193770
#
#                                                      isbn  \
# 0                                           9782221243596
# 1                                           9789049807245
# 2                                           9789028422087
# 3       9056175629, 9057593211, 9789056175627, 9789057...
# 4                                           9789403185705
# ...                                                   ...
# 104610                          2849020664, 9782849020661
# 104611                          9066484276, 9789066484276
# 104612                                      9789066488427
# 104613                                      9789460772832
# 104614                                      9789030136309
#
#                                                book_title  \
# 0                                             Noa : roman
# 1       Zondagskind : alsof opgroeien nog niet lastig ...
# 2                            Bekentenissen van een burger
# 3                                 Mijn broer bijvoorbeeld
# 4                                         De vreemdelinge
# ...                                                   ...
# 104610  Le nouveau petit Robert : dictionnaire alphabé...
# 104611  Van Dale groot woordenboek van de Nederlandse ...
# 104612         Van Dale beeldwoordenboek Nederlands-Turks
# 104613  Het Groene Boekje : woordenlijst Nederlandse taal
# 104614                       Plantyn algemene wereldatlas
#
#                     original_title  \
# 0                              NaN
# 1                              NaN
# 2            Egy polgár vallomásai
# 3       Am Beispiel meines Bruders
# 4                     La straniera
# ...                            ...
# 104610                         NaN
# 104611                         NaN
# 104612  The mini visual dictionary
# 104613                         NaN
# 104614                         NaN
#
#                                              book_summary  \
# 0       "9 hackers combattent un dictateur. Des vies s...
# 1                                                     NaN
# 2       Autobiografisch relaas van een jeugd voor de E...
# 3       Autobiografisch getint relaas waarin een Duits...
# 4       Het levensverhaal van de auteur waarin ze besc...
# ...                                                   ...
# 104610  Découvrez la vie des mots : leur étymologie et...
# 104611                                                NaN
# 104612                                                NaN
# 104613                                                NaN
# 104614                                                NaN
#
#                                        publisher          collation  \
# 0          Paris : Robert Laffont/Versilio, 2022      367 p. : ill.
# 1              [Amsterdam] : Dwarsligger, © 2019     971 p. ; 12 cm
# 2       Amsterdam : Wereldbibliotheek, cop. 2007             463 p.
# 3                       Amsterdam : Podium, 2004             151 p.
# 4                Amsterdam : De Bezige Bij, 2020             284 p.
# ...                                          ...                ...
# 104610     Paris : Dictionnaires Le Robert, 2005    XXXVII, 2949 p.
# 104611     Utrecht : Van Dale Lexicografie, 2005     3 dl. + cd-rom
# 104612                  Utrecht : Van Dale, 2010  VI, 598 p. : ill.
# 104613                  Utrecht : Van Dale, 2015            1207 p.
# 104614                  Mechelen : Plantyn, 2015   X, 191 p. : ill.
#
#                  edition  ... language original_language  \
# 0                    NaN  ...      FRE               NaN
# 1                    NaN  ...      DUT               NaN
# 2                    NaN  ...      DUT               HUN
# 3                    NaN  ...      DUT               GER
# 4                    NaN  ...      DUT               ITA
# ...                  ...  ...      ...               ...
# 104610         Nouv. éd.  ...      FRE               NaN
# 104611  14de herz. uitg.  ...      DUT               NaN
# 104612                 1  ...      DUT               ENG
# 104613                 1  ...      DUT               NaN
# 104614       Editie 2012  ...      DUT               NaN
#
#                          location  item_type  \
# 0       de Bib Leuven Tweebronnen         B2
# 1       de Bib Leuven Tweebronnen         B2
# 2       de Bib Leuven Tweebronnen         B2
# 3       de Bib Leuven Tweebronnen         B2
# 4       de Bib Leuven Tweebronnen         B2
# ...                           ...        ...
# 104610      Hulpgevangenis Leuven         ZZ
# 104611      Hulpgevangenis Leuven         ZZ
# 104612      Hulpgevangenis Leuven         ZZ
# 104613      Hulpgevangenis Leuven         ZZ
# 104614      Hulpgevangenis Leuven         ZZ
#
#                                                     genre  \
# 0                                Ideeënliteratuur, Romans
# 1       Autobiografische literatuur, Ontwikkelingsroma...
# 2        Autobiografische literatuur, Ontwikkelingsromans
# 3                             Autobiografische literatuur
# 4                     Autobiografische literatuur, Romans
# ...                                                   ...
# 104610
# 104611
# 104612
# 104613
# 104614
#
#                                                     topic  \
# 0                                                  Hacken
# 1       Autismespectrumstoornissen, Tijdsbeeld; 1980-1...
# 2       Europa; 1900-1945, Oostenrijks-Hongaarse monar...
# 3       Kinderen van nazi's, Schuldvraag; Wereldoorlog...
# 4                           Doofheid, Durastanti, Claudia
# ...                                                   ...
# 104610                         Franse taal; woordenboeken
# 104611                    Nederlandse taal; woordenboeken
# 104612                    Turkse taal; beeldwoordenboeken
# 104613                               Nederlandse spelling
# 104614                                     Wereldatlassen
#
#                                          additional_topic  \
# 0
# 1       Autisme, Aspergersyndroom, Ontwikkelingsromans...
# 2       Europa, 1900 - 1945, Autobiografische literatu...
# 3       autobiografieën, Wereldoorlog II, Autobiografi...
# 4       autobiografieën, Waargebeurd, doofheid, Autobi...
# ...                                                   ...
# 104610
# 104611  Nederlandse taal ; woordenboeken, Nederlands w...
# 104612  Nederlandse taal voor anderstaligen, Taalpunt,...
# 104613  woordenboeken, Nederlandse taal, spelling, Taa...
# 104614
#
#                                                 df_merged  \
# 0                      Ideeënliteratuur, Romans, , Hacken
# 1       Autobiografische literatuur, Ontwikkelingsroma...
# 2       Autobiografische literatuur, Ontwikkelingsroma...
# 3       Autobiografische literatuur, autobiografieën, ...
# 4       Autobiografische literatuur, Romans, autobiogr...
# ...                                                   ...
# 104610                       , Franse taal; woordenboeken
# 104611  , Nederlandse taal ; woordenboeken, Nederlands...
# 104612  , Nederlandse taal voor anderstaligen, Taalpun...
# 104613  , woordenboeken, Nederlandse taal, spelling, T...
# 104614                                   , Wereldatlassen
#
#                                               merged_info text_length
# 0       Ideeënliteratuur, Romans, , Hacken Levy, Marc ...         485
# 1       Autobiografische literatuur, Ontwikkelingsroma...         332
# 2       Autobiografische literatuur, Ontwikkelingsroma...         540
# 3       Autobiografische literatuur, autobiografieën, ...         469
# 4       Autobiografische literatuur, Romans, autobiogr...         711
# ...                                                   ...         ...
# 104610  , Franse taal; woordenboeken Robert, Paul FRE ...         480
# 104611  , Nederlandse taal ; woordenboeken, Nederlands...         154
# 104612  , Nederlandse taal voor anderstaligen, Taalpun...         278
# 104613  , woordenboeken, Nederlandse taal, spelling, T...         182
# 104614  , Wereldatlassen Plantyn algemene wereldatlas ...          74
#
# [104615 rows x 24 columns]

# %%
# check if the text length is higher than 512
long_texts = df[df['text_length']>512]
# get the index number of long texts
ind_long_text = long_texts.index
df[df['text_length']>512]
# Out:
#          index   exem_id  titelnr  \
# 4            4  16831632  1922287
# 6            6  16835335   866371
# 7            7  16835912  1329588
# 11          11  16846870  1920905
# 14          14  16849060  2106083
# ...        ...       ...      ...
# 104575  104575  17729436  3481245
# 104587  104587  16881093   432419
# 104588  104588  16912698   388058
# 104589  104589  16922707   409846
# 104607  104607  17115055  1254037
#
#                                                      isbn  \
# 4                                           9789403185705
# 6                                           9789029084789
# 7                                           9789462671416
# 11                                          9789046826492
# 14                                          9789029541565
# ...                                                   ...
# 104575                                      9780062366986
# 104587  074754624X, 0747550999, 9780747546245, 9780747...
# 104588  0747532699, 0747532745, 9780747532699, 9780747...
# 104589  0747542155, 9780747542155, 0747546290, 9780747...
# 104607                                      9781419717918
#
#                                                book_title  \
# 4                                         De vreemdelinge
# 6       Een dramatische liefde : briefwisseling Ingebo...
# 7                    Mijn Congo : een familiegeschiedenis
# 11                  Trouw : aan mijn man en zijn minnares
# 14                                         Liefdesbrieven
# ...                                                   ...
# 104575                                  Forest of secrets
# 104587                Harry Potter and the goblet of fire
# 104588           Harry Potter and the philosopher's stone
# 104589           Harry Potter and the prisoner of Azkaban
# 104607                                      Extreme earth
#
#                  original_title  \
# 4                  La straniera
# 6       Herzzeit : Briefwechsel
# 7                           NaN
# 11                          NaN
# 14                          NaN
# ...                         ...
# 104575                      NaN
# 104587                      NaN
# 104588                      NaN
# 104589                      NaN
# 104607                      NaN
#
#                                              book_summary  \
# 4       Het levensverhaal van de auteur waarin ze besc...
# 6       Paul Celan was een stateloze, Duitssprekende j...
# 7       Michael, Jos en Bart: drie generaties Demytten...
# 11      Sarah is eind dertig en woont met haar gezin o...
# 14      In 1912 verscheen de tiendelige serie 'Brieven...
# ...                                                   ...
# 104575  The third book in Erin Hunter’s #1 nationally ...
# 104587  The summer holidays are dragging on and Harry ...
# 104588  Harry Potter is an ordinary boy who lives in a...
# 104589  When Harry and his best friends go back for th...
# 104607  Extreme Earth represents an extraordinary achi...
#
#                                             publisher            collation  \
# 4                     Amsterdam : De Bezige Bij, 2020               284 p.
# 6                   Amsterdam : Meulenhoff, cop. 2010        334 p. : ill.
# 7                                 Berchem : EPO, 2018        419 p. : ill.
# 11              [Amsterdam] : Nieuw Amsterdam, © 2020               159 p.
# 14      Amsterdam : Uitgeverij De Arbeiderspers, 2020               389 p.
# ...                                               ...                  ...
# 104575                        New York : Harper, 2015  312 p. 20 p. : ill.
# 104587                      London : Bloomsbury, 2000               636 p.
# 104588                      London : Bloomsbury, 1997               223 p.
# 104589                      London : Bloomsbury, 1999               317 p.
# 104607                        New York : Abrams, 2015        446 p. : ill.
#
#                           edition  ... language original_language  \
# 4                             NaN  ...      DUT               ITA
# 6                               1  ...      DUT               GER
# 7                             NaN  ...      DUT               NaN
# 11                            NaN  ...      DUT               NaN
# 14               Herziene uitgave  ...      DUT               NaN
# ...                           ...  ...      ...               ...
# 104575  Revised paperback edition  ...      ENG               NaN
# 104587                        NaN  ...      ENG               NaN
# 104588                        NaN  ...      ENG               NaN
# 104589                        NaN  ...      ENG               NaN
# 104607                        NaN  ...      ENG               GER
#
#                          location  item_type  \
# 4       de Bib Leuven Tweebronnen         B2
# 6       de Bib Leuven Tweebronnen         B2
# 7       de Bib Leuven Tweebronnen         B2
# 11      de Bib Leuven Tweebronnen         B2
# 14      de Bib Leuven Tweebronnen         B2
# ...                           ...        ...
# 104575      Hulpgevangenis Leuven         B4
# 104587      Hulpgevangenis Leuven         B4
# 104588      Hulpgevangenis Leuven         B4
# 104589      Hulpgevangenis Leuven         B4
# 104607      Hulpgevangenis Leuven         ZZ
#
#                                                 genre  \
# 4                 Autobiografische literatuur, Romans
# 6                Autobiografische literatuur, Brieven
# 7       Autobiografische literatuur, Familiekronieken
# 11                        Autobiografische literatuur
# 14               Autobiografische literatuur, Brieven
# ...                                               ...
# 104575                        Dierenverhalen, Fantasy
# 104587                      Fantasy, Verfilmde boeken
# 104588                      Fantasy, Verfilmde boeken
# 104589                      Fantasy, Verfilmde boeken
# 104607
#
#                                                     topic  \
# 4                           Doofheid, Durastanti, Claudia
# 6                         Bachmann, Ingeborg, Celan, Paul
# 7       Demyttenaere, Bart, Congo (Eerste Republiek) (...
# 11                       Ontrouw, Domogala, Sarah (1978-)
# 14                                              Multatuli
# ...                                                   ...
# 104575                                             Katten
# 104587                   Magie, Potter, Harry (personage)
# 104588                   Magie, Potter, Harry (personage)
# 104589                   Magie, Potter, Harry (personage)
# 104607                             Aarde; luchtfotografie
#
#                                          additional_topic  \
# 4       autobiografieën, Waargebeurd, doofheid, Autobi...
# 6       autobiografieën, brieven, Autobiografische lit...
# 7       Afrika, autobiografieën, Kongo, Zaïre, Waargeb...
# 11      Autobiografische literatuur, Waar gebeurd, Dom...
# 14                   brieven, Autobiografische literatuur
# ...                                                   ...
# 104575
# 104587  Avonturenromans, Avonturenverhalen, fantasy, F...
# 104588  Avonturenverhalen, fantasy, fantasie, avontuur...
# 104589  Avonturenverhalen, magie, fantasy, Verfilmde b...
# 104607
#
#                                                 df_merged  \
# 4       Autobiografische literatuur, Romans, autobiogr...
# 6       Autobiografische literatuur, Brieven, autobiog...
# 7       Autobiografische literatuur, Familiekronieken,...
# 11      Autobiografische literatuur, Waar gebeurd, Dom...
# 14      Autobiografische literatuur, Brieven, brieven,...
# ...                                                   ...
# 104575                  Dierenverhalen, Fantasy, , Katten
# 104587  Fantasy, Verfilmde boeken, Avonturenromans, Av...
# 104588  Fantasy, Verfilmde boeken, Avonturenverhalen, ...
# 104589  Fantasy, Verfilmde boeken, Avonturenverhalen, ...
# 104607                           , Aarde; luchtfotografie
#
#                                               merged_info text_length
# 4       Autobiografische literatuur, Romans, autobiogr...         711
# 6       Autobiografische literatuur, Brieven, autobiog...         803
# 7       Autobiografische literatuur, Familiekronieken,...        1690
# 11      Autobiografische literatuur, Waar gebeurd, Dom...        1361
# 14      Autobiografische literatuur, Brieven, brieven,...         939
# ...                                                   ...         ...
# 104575  Dierenverhalen, Fantasy, , Katten Hunter, Erin...         738
# 104587  Fantasy, Verfilmde boeken, Avonturenromans, Av...         841
# 104588  Fantasy, Verfilmde boeken, Avonturenverhalen, ...        1117
# 104589  Fantasy, Verfilmde boeken, Avonturenverhalen, ...         741
# 104607  , Aarde; luchtfotografie Martin, Michael ENG E...         906
#
# [15220 rows x 24 columns]

# %% [markdown]
# ### 2-Calculating Similarities of Contents

# %% [markdown]
# #### a- Creating Embeddings for Texts

# %%
# this computes embeddings_matrix using distilbert-base-multilingual-cased model.
# one can use the output of this cell as the input to cosine similarity 
# takes 17 mins to run
import pandas as pd
import numpy as np
from transformers import AutoTokenizer, AutoModel
import torch
import random 

seed_value = 42

random.seed(seed_value)
np.random.seed(seed_value)
torch.manual_seed(seed_value)
torch.cuda.manual_seed_all(seed_value) 

# Load pre-trained multilingual model and tokenizer
model_name = 'distilbert-base-multilingual-cased' 
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name).to('cuda')  # move model to GPU

# Define function to get embeddings for a text
def get_embeddings(text):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True).to('cuda')
    outputs = model(**inputs).last_hidden_state.mean(dim=1)
    return outputs.cpu().detach().numpy()[0]

# Get the number of books
num_books = len(df)

# Initialize the matrix to store embeddings
embeddings_matrix = np.zeros((num_books, 768))

# Iterate over the DataFrame and get embeddings for each merged_info
for i, row in df.iterrows():
    embeddings_matrix[i] = get_embeddings(row['merged_info'])

embeddings_matrix

# %%
# Save the embeddings matrix as a .npy file
np.save('embeddings_matrix.npy', embeddings_matrix)

# %%
# Load the embeddings matrix from the .npy file
embeddings_matrix = np.load('embeddings_matrix.npy')

# %%
# save the array as a csv file
np.savetxt('embeddings_matrix.csv', embeddings_matrix, delimiter=',')

# %% [markdown]
# #### b- Cosine Similarity Calculation

# %%
# This calculates cosine similarity between each book read by readers and each unique 
# book available in the library. Due to memory issues, it calculates the books 
#in batches of 9000 and assign it as 'cosine_similarity_df<batch number>.npy' then clean the memory.

import torch
import numpy as np

# Convert embeddings to a PyTorch tensor
# cuda is used for GPU/TPU usage
embedding_tensor = torch.tensor(embeddings_matrix).to('cuda')

for j in range(11):
  data = data1[j*9000 : (j+1)*9000]
  cosine_similarity_matrix = np.zeros((len(data), 105163))
  for i in range(len(data)):
    titelnr = data.iloc[i]['book_title_id']
    book_i_embeddings = embedding_tensor[df[df['book_title_id']==titelnr]['index'].index[0]]
    cosine_similarities = torch.cosine_similarity(book_i_embeddings.unsqueeze(0).to('cuda'), embedding_tensor, dim=1)
    cosine_similarity_matrix[i,:] = cosine_similarities.cpu().numpy()
  # Assign cosine similarity matrix to a new DataFrame
  cosine_similarity_df = pd.DataFrame(cosine_similarity_matrix, index=data['book_title_id'])
  # Convert the DataFrame to a NumPy array
  array = cosine_similarity_df.values
  # Save the embeddings matrix as a .npy file
  print(j)
  np.save(f'cosine_similarity_df{j+1}.npy', array)
  array = np.zeros(1)
  cosine_similarity_df = pd.DataFrame(array)

# %% [markdown]
# ### Creating top-10 book recommendation for each interaction

# %%
# Read the book_title_map for mapping the book titles with the unique title numbers
book_title_map = pd.read_csv("book_title_id_mapping.csv", sep=',').reset_index()
book_title_map

# %%
# define a function to get the top 10 highest values 
#that are smaller than 0.989 and their corresponding column numbers
def get_top_10(row):
    top_10 = row[row < 0.989].nlargest(20)
    return pd.DataFrame({'index': [row.name] * len(top_10),
                         'top10book': top_10.index,
                         'similarity': top_10.values})

# %%
# load the numpy array of cosine similarities
array = np.load(f'cosine_similarity_df{i+1}.npy')
# convert the numpy array to a pandas DataFrame
df = pd.DataFrame(array)
array = np.zeros(1)
df

# %%
# get the full list of books and their unique title numbers 
books_full_list = pd.read_csv("books_with_book_title_id.csv", sep=',')
books_full_list = books_full_list.drop(['level_0', 'Unnamed: 0'], axis=1).reset_index()
books_full_list = books_full_list.rename(columns={'book_title_id': 'book_title_id_cbf'})
books_full_list

# %%
unique_books_index = books_full_list.drop_duplicates(['book_title_id_cbf']).index
unique_books_index

# %%
# for each 'cosine_similarity_df<batch number>.npy' this code applies get_top_10 function for each column
# assigns the top-10 similar book ids and summaries to top10book and similarity columns respectively.
for i in range(11):
  # load the numpy array
  array = np.load(f'cosine_similarity_df{i+1}.npy')
  # convert the numpy array to a pandas DataFrame
  df = pd.DataFrame(array)
  array = np.zeros(1)
  df = df[unique_books_index]
  # apply the function to each row in the dataframe and concatenate the results
  result_df = pd.concat(df.apply(get_top_10, axis=1).tolist(), ignore_index=True)
  result_df['index'] = result_df['index']+ (9000*i) 
  df = pd.DataFrame(array)
  # merge the two dataframes based on the common column
  merged_df = pd.merge(result_df, book_title_map, left_on='index', right_on='index')
  merged_df = merged_df[['index', 'book_title_id', 'top10book', 'similarity']]
  merged_df.to_csv(f'top10book_{i*9000}_{(i+1)*9000}_2.csv')
  print(i)

# %% [markdown]
# #### Make Top-10 Recommendations Using Cosine Similarity Matrix

# %%
# Get the index values of the books for mapping
book_title_index = pd.read_csv("book_hist_loan_titleid_index.csv", sep=',')
book_title_index= book_title_index.drop(['Unnamed: 0'], axis=1).reset_index()
book_title_index

# %%
# Create a empty array and fill it with the 'top10book_<batch>_<batch>.csv' files 
# append all of them in a data frame 
dfs = []

for i in range(11):
    filename = "top10book_" + str(i*9000) + "_" + str(i*9000+9000) + ".csv"
    df = pd.read_csv(filename, sep=',')
    df = df[['index', 'book_title_id', 'top10book', 'similarity']]
    dfs.append(df)

# Concatenate all dataframes together
df = pd.concat(dfs, ignore_index=True)
df

# %%
# Get the unique actor id list
actor_id_list = book_title_index['actor_id'].unique()
actor_id_list

# %%
# Create an empty actor_df data frame which has columns actor_id, recommendations, similarities
actor_df = pd.DataFrame({'actor_id': actor_id_list,
                   'recommendations': [[] for _ in range(len(actor_id_list))],
                   'similarities': [[] for _ in range(len(actor_id_list))]})
actor_df

# %%
# For each actor, get the top-10 book recommendations and the corresponding similarities and store in the rows of this dataframe
for i in range(len(actor_id_list)):
  book_title_list = book_title_index[book_title_index['actor_id']== actor_id_list[i]]
  books_recommended = df[df['book_title_id'].isin(book_title_list['book_title_id'].to_list())].sort_values(by='similarity', ascending=False).drop_duplicates(['top10book']).head(10)
  actor_df['recommendations'][i].append(books_recommended['top10book'].to_list())
  actor_df['similarities'][i].append(books_recommended['similarity'].to_list())
actor_df['recommendations'] = actor_df['recommendations'].apply(lambda x: x[0])
actor_df['similarities'] = actor_df['similarities'].apply(lambda x: x[0])
actor_df
